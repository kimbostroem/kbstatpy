# %% [markdown]
# # kbstatpy — run the demos on Google Colab
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/kimbostroem/kbstatpy/blob/master/demos/kbstatpy_colab.ipynb)
#
# Try [**kbstatpy**](https://github.com/kimbostroem/kbstatpy) — generalised linear
# mixed-model analysis with post-hoc comparisons, data transformation, correlation
# analysis, and VIF — on a free Google Colab runtime. No local install, and no R to
# set up on your own machine: Colab already ships R and `rpy2`.
#
# ## How to use this notebook
#
# 1. **Run the Setup cell** once — it installs kbstatpy, its R packages, and the
#    demo data (~1–2 min).
# 2. Run the **inline example** to see a complete analysis — ANOVA table, post-hoc
#    comparisons, and plots — rendered right here.
# 3. **Run any of the 15 demos in this same session** with the *Run any demo* cell —
#    no new runtime, no re-install. (Each demo is also available as its own
#    standalone notebook; see the links at the bottom.)
#
# > **Whose notebook is this?** The moment you run or edit a cell, Colab keeps a
# > private copy in your own Google account (*File → Save a copy in Drive*). You can
# > experiment freely — you will not change anyone else's copy.

# %% [markdown]
# ## Setup — install kbstatpy, its R packages & the demo data
#
# Run this once (~1–2 min). It clones the repo, installs kbstatpy so the running
# kernel can import it, links the bundled datasets, and installs the R packages
# kbstatpy relies on. Safe to re-run — it refreshes to the latest version.

# %%
# !curl -sSL https://raw.githubusercontent.com/kimbostroem/kbstatpy/master/demos/colab_setup.sh | bash

# %% [markdown]
# ## Inline example — Demo 1 (unpaired *t*-test equivalent)
#
# A linear model with a single two-level factor reproduces the classical
# independent-samples *t*-test exactly, on the classic `sleep` dataset. Running the
# cell below renders the ANOVA table, post-hoc comparison, and data plot inline;
# nothing is written to disk (`out_dir` is empty).
#
# To try your own data, point `in_file` at any file in the bundled `data/` folder
# (`toothgrowth.csv`, `iris.csv`, `sleepstudy.csv`, …) and adjust `y` / `x`.

# %%
import os
import matplotlib.pyplot as plt
from kbstatpy import Kbstat, KbstatOptions

options = KbstatOptions()
options.in_file = os.path.join(options.demo_dir, 'data/sleep.csv')
options.out_dir = ''            # '' -> show inline only; set a folder to also save files
options.y       = 'extra'
options.y_units = 'h'
options.x       = 'group'
options.rename  = 'extra -> ExtraSleep; group -> DrugGroup'

kb = Kbstat(options)
kb.run();                       # fit + ANOVA + post-hoc + plots, rendered inline

# %% [markdown]
# ## Run any demo — here, in this session
#
# Set `demo` below and run the cell. It loads that demo's configuration and runs it
# with `run()`, so the tables and figures render **inline** (nothing written to
# disk) in the kernel you already set up — **no new runtime and no re-install**.
#
# ```
# demo_01_unpaired        demo_06_lmm_slopes             demo_11_glmm_binomial
# demo_02_paired          demo_07_lmm_transform          demo_12_multi_y
# demo_03_twoway          demo_08_glmm_gamma             demo_13_family_correction
# demo_04_lmm             demo_09_lmm_partial_interaction demo_14_lm_vif
# demo_05_correlation     demo_10_outliers               demo_15_posthoc_compare
# ```
#
# See the [README demo table](https://github.com/kimbostroem/kbstatpy#demo-scripts)
# for what each one shows.

# %%
import os
from kbstatpy import KbstatOptions

demo = 'demo_08_glmm_gamma'      # <- change to any demo name from the list above

# Load the demo's script and run it inline, swapping run_save() -> run() so it
# renders tables + figures here without writing files. Runs in THIS session.
path = os.path.join(KbstatOptions().demo_dir, 'scripts', demo + '.py')
exec(open(path).read().replace('run_save()', 'run()'))

# %% [markdown]
# ## Open a demo as its own notebook
#
# Each demo also has a **standalone notebook** — handy for sharing a single example
# or working on one in isolation. Note that opening one starts a **fresh Colab
# runtime** (the setup runs again there); to try several demos quickly without
# re-installing, use the *Run any demo* cell above instead.
#
# - [Demo 1 — Unpaired *t*-test equivalent](https://colab.research.google.com/github/kimbostroem/kbstatpy/blob/master/demos/notebooks/demo_01_unpaired.ipynb)
# - [Demo 2 — Paired *t*-test equivalent](https://colab.research.google.com/github/kimbostroem/kbstatpy/blob/master/demos/notebooks/demo_02_paired.ipynb)
# - [Demo 3 — Two-way ANOVA equivalent](https://colab.research.google.com/github/kimbostroem/kbstatpy/blob/master/demos/notebooks/demo_03_twoway.ipynb)
# - [Demo 4 — One-way RM-ANOVA (LMM)](https://colab.research.google.com/github/kimbostroem/kbstatpy/blob/master/demos/notebooks/demo_04_lmm.ipynb)
# - [Demo 5 — Standalone correlation analysis](https://colab.research.google.com/github/kimbostroem/kbstatpy/blob/master/demos/notebooks/demo_05_correlation.ipynb)
# - [Demo 6 — LMM with random slopes](https://colab.research.google.com/github/kimbostroem/kbstatpy/blob/master/demos/notebooks/demo_06_lmm_slopes.ipynb)
# - [Demo 7 — LMM with log-transform](https://colab.research.google.com/github/kimbostroem/kbstatpy/blob/master/demos/notebooks/demo_07_lmm_transform.ipynb)
# - [Demo 8 — GLMM (gamma, log link)](https://colab.research.google.com/github/kimbostroem/kbstatpy/blob/master/demos/notebooks/demo_08_glmm_gamma.ipynb)
# - [Demo 9 — LMM with partial interaction](https://colab.research.google.com/github/kimbostroem/kbstatpy/blob/master/demos/notebooks/demo_09_lmm_partial_interaction.ipynb)
# - [Demo 10 — Outlier removal (pre/post-fit)](https://colab.research.google.com/github/kimbostroem/kbstatpy/blob/master/demos/notebooks/demo_10_outliers.ipynb)
# - [Demo 11 — GLMM (binomial, logit link)](https://colab.research.google.com/github/kimbostroem/kbstatpy/blob/master/demos/notebooks/demo_11_glmm_binomial.ipynb)
# - [Demo 12 — Multiple dependent variables + correlation](https://colab.research.google.com/github/kimbostroem/kbstatpy/blob/master/demos/notebooks/demo_12_multi_y.ipynb)
# - [Demo 13 — Family-wise correction across DVs](https://colab.research.google.com/github/kimbostroem/kbstatpy/blob/master/demos/notebooks/demo_13_family_correction.ipynb)
# - [Demo 14 — LM with mixed predictors + VIF](https://colab.research.google.com/github/kimbostroem/kbstatpy/blob/master/demos/notebooks/demo_14_lm_vif.ipynb)
# - [Demo 15 — `posthoc_compare` across factors](https://colab.research.google.com/github/kimbostroem/kbstatpy/blob/master/demos/notebooks/demo_15_posthoc_compare.ipynb)

# %% [markdown]
# ---
#
# **More:** [README](https://github.com/kimbostroem/kbstatpy#readme) ·
# [Statistical notes](https://github.com/kimbostroem/kbstatpy/blob/master/STATISTICAL_NOTES.md) ·
# [Options reference](https://github.com/kimbostroem/kbstatpy#options-reference)
